# %%
import ast
import csv

# Step 1: Read the TXT file
with open('depop.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit

# Step 3: Convert to CSV
csv_file = 'output.csv'
csv_columns = ['id', 'slug', 'status', 'hasVideo', 'priceAmount', 'currencyName', 'nationalShippingCost', 'preview150', 'preview210', 'preview320', 'preview480', 'preview640', 'preview960', 'preview1280', 'variantSetId', 'variants', 'isLiked', 'brandId']

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        # Prepare data for each row
        row = {
            'id': item['id'],
            'slug': item['slug'],
            'status': item['status'],
            'hasVideo': item['hasVideo'],
            'priceAmount': item['price']['priceAmount'],
            'currencyName': item['price']['currencyName'],
            'nationalShippingCost': item['price'].get('nationalShippingCost', 'N/A'),
            # Extract preview URLs based on available keys
            **{f'preview{k}': item['preview'].get(k, 'N/A') for k in ['150', '210', '320', '480', '640', '960', '1280']},
            'variantSetId': item.get('variantSetId', 'N/A'),
            'variants': item.get('variants', {}),
            'isLiked': item['isLiked'],
            'brandId': item.get('brandId', 'N/A')
        }
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 5
#       2 import csv
#       4 # Step 1: Read the TXT file
# ----> 5 with open('depop.txt', 'r') as file:
#       6     data = file.read()
#       8 # Step 2: Parse the data using ast.literal_eval
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'depop.txt'

# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')
df
# Out:
#             id                                               slug  status  \
# 0    320656600      bossladyjen-the-original-penguin-board-shorts  ONSALE
# 1    311739781          specialkrocks-size-xl-excellent-condition  ONSALE
# 2    245637157         phoebelin14-club-monaco-pants-trouser-like  ONSALE
# 3    327774978              hautelife-mk-michael-kors-knit-gloves  ONSALE
# 4    327474759   jellopop7-studio-ghibli-my-neighbour-totoro-436f  ONSALE
# ..         ...                                                ...     ...
# 395  326934281               rodriguedwin-1990s-vintage-pure-wool  ONSALE
# 396  326878899  norahloveboutique-vintage-80s-floral-tiered-dr...  ONSALE
# 397  326325619          bellaroo2-crocheted-market-tote-made-with  ONSALE
# 398  326205039                  ma2dax-britts-knit-brand-new-with  ONSALE
# 399  325887821  olebuds-corona-halloween-shirt-corona-coronashirt  ONSALE
#
#      hasVideo  priceAmount currencyName  nationalShippingCost  \
# ...

# %%
import ast
import csv

# Step 1: Read the TXT file
with open('mercari.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit

# Step 3: Convert to CSV
csv_file = 'mercari.csv'
# Define the CSV columns, including nested attributes and handling multiple photos
csv_columns = [
    'id', 'name', 'status', 'description', 'originalPrice', 'price', 'shippingPayerName',
    'itemCategoryNameLevel0', 'itemCategoryNameLevel1', 'itemCategoryNameLevel2',
    'photoLarge1', 'photoThumbnail1', 'photoLarge2', 'photoThumbnail2',  # Assuming at most 2 photos for simplicity
    'brandName', 'itemSizeName', 'itemConditionName', 'categoryTitle', 'categoryId'
]

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        # Flatten the data structure for CSV output
        row = {
            'id': item['id'],
            'name': item['name'],
            'status': item['status'],
            'description': item['description'].replace('\n', ' '),  # Replace newlines in description
            'originalPrice': item['originalPrice'],
            'price': item['price'],
            'shippingPayerName': item['shippingPayer']['name'],
            'itemCategoryNameLevel0': item['itemCategoryHierarchy'][0]['name'] if item['itemCategoryHierarchy'] else '',
            'itemCategoryNameLevel1': item['itemCategoryHierarchy'][1]['name'] if len(item['itemCategoryHierarchy']) > 1 else '',
            'itemCategoryNameLevel2': item['itemCategoryHierarchy'][2]['name'] if len(item['itemCategoryHierarchy']) > 2 else '',
            'photoLarge1': item['photos'][0]['large'] if item['photos'] else '',
            'photoThumbnail1': item['photos'][0]['thumbnail'] if item['photos'] else '',
            'photoLarge2': item['photos'][1]['large'] if len(item['photos']) > 1 else '',
            'photoThumbnail2': item['photos'][1]['thumbnail'] if len(item['photos']) > 1 else '',
            'brandName': item['brand']['name'] if item['brand'] else '',
            'itemSizeName': item['itemSize']['name'] if item['itemSize'] else '',
            'itemConditionName': item['itemCondition']['name'],
            'categoryTitle': item['categoryTitle'],
            'categoryId': item['categoryId']
        }
        writer.writerow(row)

# %%
df = pd.read_csv("mercari.csv")
df
# Out:
#                id                                               name   status  \
# 0    m22320342524                           Lululemon aling tank top  trading
# 1    m85357578668     Disney's Lilo Stitch Christmas Cookie Canistet  trading
# 2    m82739392053     NEW Starbucks** Purple Diamond Studded Clemson  trading
# 3    m31686211653  Under Armour SpeedForm Gemini 2 Navy Running S...  trading
# 4    m80640609377  Rifle Paper Co Company Grey Next Level T Shirt...  trading
# ..            ...                                                ...      ...
# 295  m98153091140      Jeremiah Brown Plaid Wool Blend Flannel Shirt  trading
# 296  m23014093895                Hallmark ornament Betsey Clark 1982  trading
# 297  m75473199672            Funko Metallic Green Power Ranger Tommy  trading
# 298  m68272874142  Hydrapak Flux - Collapsible Backpacking Water ...  trading
# 299  m60880115117  APL Athletic Propulsion Labs Techloom Phantom ...  trading
#
# ...

# %%
import ast
import csv

# Step 1: Read the TXT file
with open('thredupTest.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit

# Step 3: Convert to CSV
csv_file = 'thredupTest.csv'
csv_columns = [
    'id', 'itemNumber', 'title', 'brand', 'brandId', 'category', 'colorNames',
    'conditionOverrides', 'departmentTags', 'favoriteCount', 'hasConditionOverrides',
    'msrp', 'price', 'sizeLabel', 'sizes', 'state', 'styleTags', 'supplierId',
    'warehouseId', 'discountPercent', 'isDynamicDiscount', 'promofiedPrice',
    'sustainabilityImpact', 'photoIds'
]

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        promotion = item.get('promotion') if item.get('promotion') else {}
        sustainabilityImpact = item.get('sustainabilityImpact') if item.get('sustainabilityImpact') else {}
        row = {
            'id': item['id'],
            'itemNumber': item['itemNumber'],
            'title': item['title'],
            'brand': item['brand'],
            'brandId': item['brandId'],
            'category': item['category'],
            'colorNames': ", ".join(item['colorNames']),
            'conditionOverrides': item['conditionOverrides'],
            'departmentTags': ", ".join(item['departmentTags']),
            'favoriteCount': item['favoriteCount'],
            'hasConditionOverrides': item['hasConditionOverrides'],
            'msrp': item['msrp'],
            'price': item['price'],
            'sizeLabel': item['sizeLabel'],
            'sizes': ", ".join(item['sizes']),
            'state': item['state'],
            'styleTags': ", ".join(item['styleTags']),
            'supplierId': item['supplierId'],
            'warehouseId': item['warehouseId'],
            'discountPercent': promotion.get('discountPercent'),
            'isDynamicDiscount': promotion.get('isDynamicDiscount'),
            'promofiedPrice': promotion.get('promofiedPrice'),
            'sustainabilityImpact': ", ".join(f"{k}: {v}" for k, v in sustainabilityImpact.items() if k != '__typename'),
            'photoIds': ", ".join(item['photoIds'])
        }
        writer.writerow(row)

# %%
df = pd.read_csv("thredupTest.csv")
df
# Out:
#              id  itemNumber                                        title  \
# 0     130654003   133655775                             Mod Cloth Blazer
# 1     119836016   122834628                   Christian Dior Ankle Boots
# 2     130021450   133023222  Rabbit Rabbit Rabbit Designs Cocktail Dress
# 3     122270041   125271837             Liz Claiborne Long Sleeve Blouse
# 4     129586634   132588406                 Rebecca Minkoff Casual Dress
# ...         ...         ...                                          ...
# 2995  117331257   120329210                                Merona Blazer
# 2996  117073536   120071488                          Dkny Jeans Jeggings
# 2997  116851599   119849550               Vince Camuto Sleeveless Blouse
# 2998  115961374   118959322                   Eliot Long Sleeve Silk Top
# 2999  115227094   118225042                      Vince. Pullover Sweater
#
#                              brand  brandId              category  \
# ...

# %%
import ast
import csv

# Assuming data is already read and stored in `items` using ast.literal_eval(data)
# Proceeding directly to Step 3: Convert to CSV
with open('poshmark.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit
csv_file = 'poshmark.csv'
csv_columns = [
    'id', 'creator_id', 'status', 'status_changed_at', 'origin_domain',
    'destination_domains', 'publish_count', 'app', 'app_version',
    'inventory_status', 'inventory_status_changed_at', 'size_quantities',
    'size_quantity_revision', 'catalog_category_features', 'catalog_department',
    'catalog_category', 'colors', 'title', 'description', 'price_val',
    'price_currency_code', 'original_price_val', 'original_price_currency_code', 'size', 'brand',
    'category', 'condition', 'cover_shot_url', 'picture_urls'
]

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        destination_domains = ", ".join(item.get('destination_domains', []))
        colors = "; ".join([f"{color['name']} ({color['rgb']})" for color in item.get('colors', [])])
        size_quantities = "; ".join([
            f"Size: {size['size_id']}, Available: {size['quantity_available']}" 
            for size in item.get('inventory', {}).get('size_quantities', [])
        ])
        picture_urls = "; ".join([pic['url'] for pic in item.get('pictures', []) if 'url' in pic])

        row = {
            'id': item['id'],
            'creator_id': item.get('creator_id', ''),
            'status': item.get('status', ''),
            'status_changed_at': item.get('status_changed_at', ''),
            'origin_domain': item.get('origin_domain', ''),
            'destination_domains': destination_domains,
            'publish_count': item.get('publish_count', 0),
            'app': item.get('app', ''),
            'app_version': item.get('app_version', ''),
            'inventory_status': item.get('inventory', {}).get('status', ''),
            'inventory_status_changed_at': item.get('inventory', {}).get('status_changed_at', ''),
            'size_quantities': size_quantities,
            'size_quantity_revision': item.get('inventory', {}).get('size_quantity_revision', 0),
            'catalog_category_features': "; ".join(item.get('catalog', {}).get('category_features', [])),
            'catalog_department': item.get('catalog', {}).get('department_obj', {}).get('display', ''),
            'catalog_category': item.get('catalog', {}).get('category_obj', {}).get('display', ''),
            'colors': colors,
            'title': item.get('title', ''),
            'description': item.get('description', ''),
            'price_val': item.get('price_amount', {}).get('val', ''),
            'price_currency_code': item.get('price_amount', {}).get('currency_code', ''),
            'original_price_val': item.get('original_price_amount', {}).get('val', ''),
            'original_price_currency_code': item.get('original_price_amount', {}).get('currency_code', ''),
            'size': item.get('size', ''),
            'brand': item.get('brand', ''),
            'category': item.get('category', ''),
            'condition': item.get('condition', ''),
            'cover_shot_url': item.get('cover_shot', {}).get('url', ''),
            'picture_urls': picture_urls
        }
        writer.writerow(row)

# %%
import pandas as pd
df4 = pd.read_csv("poshmark.csv")
df4.head()
# Out:
#                          id                creator_id     status  \
# 0  5ef267713a0db9382c1f3e80  5b116bb3c4f7ac48d82c9de9  published
# 1  636b0943a0e6c6f1783de23e  5c65e4ffbce4893171fd2af8  published
# 2  636d22adbeca4ef01d03faf7  5e31e11da3f29dff83237a92  published
# 3  615a10f9ce1e8714c8c564ab  5db254376e32392b2495925c  published
# 4  5ff442f71c528acfb5fe8453  5ab21c90b9340149b1759acd  published
#
#            status_changed_at origin_domain destination_domains  publish_count  \
# 0  2022-11-20T09:01:52-08:00            us                  us             12
# 1  2022-11-19T18:34:04-08:00            us                  us              2
# 2  2022-11-17T12:14:20-08:00            us                  us              5
# 3  2022-11-04T18:50:39-07:00            us                  us              9
# 4  2021-10-29T12:50:47-07:00            us                  us              3
#
#       app app_version inventory_status  ... price_val price_currency_code  \
# ...

# %%
import ast
import csv

# Step 1: Read the TXT file
with open('depopDetailed.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit

# Step 3: Convert to CSV
csv_file = 'depopDetailed.csv'
csv_columns = [
    'id', 'address', 'countryCode', 'brand', 'brandId', 'categoryId', 'price',
    'currencyName', 'priceAmount', 'nationalShippingCost', 'dateUpdated',
    'description', 'pictures', 'width', 'height', 'url', 'username', 'reviewsRating',
    'reviewsTotal', 'itemsSold', 'lastSeen', 'firstName',
    'lastName', 'condition', 'colour', 'group', 'attributes', 'productType', 'gender', 'isKids'
]

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        promotion = item.get('promotion') if item.get('promotion') else {}
        sustainabilityImpact = item.get('sustainabilityImpact') if item.get('sustainabilityImpact') else {}
        row = {
            'id': item['id'],
            'address': item['address'],
            'countryCode': item['countryCode'],
            'brand': item['brand'],
            'brandId': item['brandId'],
            'categoryId': item['categoryId'],
            'currencyName': item['price']['currencyName'],
            'priceAmount': item['price']['priceAmount'],
            'nationalShippingCost': item['price'].get('nationalShippingCost', 'N/A'),
            'dateUpdated': item['dateUpdated'],
            'description': item.get('description', ''),
            'pictures': item['pictures'],
            'width': item.get('width', ''),
            'height': item.get('height', ''),
            'url': item.get('url', ''),
            'username': item.get('username', ''),
            'reviewsRating': item.get('reviewsRating', ''),
            'reviewsTotal': item.get('reviewsTotal', ''),
            'itemsSold': item.get('itemsSold', ''),
            'lastSeen': item.get('lastSeen', ''),
            'firstName': item.get('firstName', ''),
            'lastName': item.get('lastName', ''),
            'condition': item.get('condition', ''),
            'colour': item.get('colour', ''),
            'group': item.get('group', ''),
            'attributes': item.get('attributes', ''),
            'productType': item.get('productType', ''),
            'gender': item.get('gender', ''),
            'isKids': item.get('isKids', ''),
           
        }
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 35
#      29 promotion = item.get('promotion') if item.get('promotion') else {}
#      30 sustainabilityImpact = item.get('sustainabilityImpact') if item.get('sustainabilityImpact') else {}
#      31 row = {
#      32     'id': item['id'],
#      33     'address': item['address'],
#      34     'countryCode': item['countryCode'],
# ---> 35     'brand': item['brand'],
#      36     'brandId': item['brandId'],
#      37     'categoryId': item['categoryId'],
#      38     'currencyName': item['price']['currencyName'],
#      39     'priceAmount': item['price']['priceAmount'],
#      40     'nationalShippingCost': item['price'].get('nationalShippingCost', 'N/A'),
#      41     'dateUpdated': item['dateUpdated'],
#      42     'description': item.get('description', ''),
#      43     'pictures': item['pictures'],
# ...

# %%
import pandas as pd
df5 = pd.read_csv("depopDetailed.csv")
df5.head()

# %%
import ast
import csv

# Step 1: Read the TXT file
with open('thredupWomans.txt', 'r') as file:
    data = file.read()

# Step 2: Parse the data using ast.literal_eval
try:
    items = ast.literal_eval(data)
except ValueError as e:
    print(f"Error parsing data: {e}")
    # Handle the error or exit

# Step 3: Convert to CSV
csv_file = 'thredupWomans.csv'
csv_columns = [
    '__typename', 'availability', 'brand', 'brandId', 'category', 'categoryTags', 'clearance', 'colorNames', 'conditionOverrides','departmentTags',
    'favoriteCount', 'favorites', 'hasConditionOverrides', 'hasInappropriateContent', 'id',
    'itemNumber', 'materials', 'merchandisingDepartment', 'msrp', 'newWithTags', 'occasionTags', 'photoIds',
    'price', 'promotion', 'sellthroughScore', 'sizeEquivalents',
    'sizeLabel', 'sizes', 'state', 'styleTags', 'supplierId', 'sustainabilityImpact'
]

with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for item in items:
        promotion = item.get('promotion') if item.get('promotion') else {}
        sustainabilityImpact = item.get('sustainabilityImpact') if item.get('sustainabilityImpact') else {}
        row = {
            '__typename': item['__typename'],
            'availability': item['availability'],
            'brand': item['brand'],
            'brandId': item['brandId'],
            'category': item['category'],
            'categoryTags': item['categoryTags'],
            'clearance': item['clearance'],
            'colorNames': item['colorNames'],
            'conditionOverrides': item['conditionOverrides'],
            'departmentTags': ", ".join(item['departmentTags']),
            'favoriteCount': item['favoriteCount'],
            'favorites': item['favorites'],
            'hasConditionOverrides': item['hasConditionOverrides'],
            'hasInappropriateContent': item['hasInappropriateContent'],
            'id': item['id'],
            'itemNumber': item['itemNumber'],
            'materials': item['materials'],
            'merchandisingDepartment': item['merchandisingDepartment'],
            'msrp': item['msrp'],
            'newWithTags': item['newWithTags'],
            'occasionTags': ", ".join(item['occasionTags']),
            'photoIds': item['photoIds'],
            'price': item['price'],
            'promotion': item['promotion'],
            'sellthroughScore': item['sellthroughScore'],
            'sizeEquivalents': item['sizeEquivalents'],
            'sizeLabel': item['sizeLabel'],
            'sizes': item.get('sizes', ''),
            'state': item['state'],
            'styleTags': ", ".join(item['styleTags']),
            'supplierId': item['supplierId'],
            'sustainabilityImpact': item['sustainabilityImpact'],          
        }
        writer.writerow(row)

# %%
pip intall pandas
# Out:
# ERROR: unknown command "intall" - maybe you meant "install"
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df6 = pd.read_csv("depopDetailed.csv")
df6.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import pandas as pd
#       2 df6 = pd.read_csv("depopDetailed.csv")
#       3 df6.head()
#
# ModuleNotFoundError: No module named 'pandas'
